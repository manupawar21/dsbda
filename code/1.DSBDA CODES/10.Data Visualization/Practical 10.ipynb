# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
df= pd.read_csv("C:\\Users\\prath\\OneDrive\\Desktop\\DSBDA CODES\\10.Data Visualization\\Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2  \
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
 df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
np.unique(df["Species"])
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
# Q2

# %%
sns.histplot(data=df, x="SepalLengthCm", kde=True , color = "Red")
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Count'>

# %%
sns.histplot(data = df , x="SepalWidthCm", kde=True, color ="Green")
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='Count'>

# %%
sns.histplot(data=df, x = "PetalLengthCm", kde= True, color = "Purple")
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Count'>

# %%
sns.histplot(data=df, x="PetalWidthCm", kde = True, color ="Black")
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='Count'>

# %%
#Q3
data = df.drop(columns = "Id")
figure = plt.figure(figsize = (12,8))
sns.boxplot(data=data)
# Out:
# <Axes: >

# %%
#Q4

# %%
## For finding outliers of particular column
from matplotlib.cbook import boxplot_stats
stats = boxplot_stats(data["SepalWidthCm"])
stats
# Out:
# [{'mean': 3.0540000000000003,
#   'iqr': 0.5,
#   'cilo': 2.9359050183971735,
#   'cihi': 3.0640949816028265,
#   'whishi': 4.0,
#   'whislo': 2.2,
#   'fliers': array([2. , 4.4, 4.1, 4.2]),
#   'q1': 2.8,
#   'med': 3.0,
#   'q3': 3.3}]

# %%
stats[0]["fliers"]
# Out:
# array([2. , 4.4, 4.1, 4.2])
